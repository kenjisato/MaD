# %% [markdown]
# ## 練習問題
#
# by kenjisato
# id: ch01-kjst04

# %% [markdown]
# ### 問題

# %% [markdown]
# ある4年間の実質GDPが
#
# $$
# \begin{aligned}
#     y_0 &= 500\\
#     y_1 &= 520\\
#     y_2 &= 550\\
#     y_3 &= 580
# \end{aligned}
# $$
#
# だった。この4年間の平均成長率を計算しなさい。

# %% [markdown]
# #### 解答
